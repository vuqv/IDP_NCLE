# %%
import pandas as pd

# %%
df_cell = pd.read_pickle('cellcom.pkl')
print(len(df_cell))
# Out:
# 96

# %%
df_mol = pd.read_pickle('molfunc.pkl')
print(len(df_mol))
# Out:
# 94

# %%
df_bio = pd.read_pickle('bioproc.pkl')
print(len(df_bio))
# Out:
# 113
